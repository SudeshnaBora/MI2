# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import warnings
warnings.filterwarnings('ignore')

# %%
def p_X(x, μ=1, b=2):
    return 1 / (2 * b) * np.exp(-(np.abs(x - μ) / b))

# %%
def F_X_inv(y, μ=1, b=2):
    lower = np.log(2 * y) * b + μ
    upper = μ - np.log(-2 * y + 2) * b
    return (y < 0.5) * lower + (y >= 0.5) * upper

# %%
samples = F_X_inv(np.random.random(500))
min_, max_ = samples.min(), samples.max()
steps = np.linspace(min_, max_, 500)
density = p_X(steps)
fig, ax = plt.subplots(ncols=1, nrows=1)
ax.plot(steps, density, label = "pdf")
ax.set_xlim(min_, max_)
ax.hist(samples, normed=True, bins=30, label = 'density estimate')
plt.legend()
plt.title('Density estimate super imposed by pdf function')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
